# %%
"This notebook tries to come up with the best possible team by combining feature selection with common sense(meaningfor instance, trying not to put a striker to leftback)"
"This is made by limiting the pool of players by position in fifa for each position. You can modify the pool of positions for each positions and explore the possibilites"
# Out:
# 'This notebook tries to come up with the best possible team by combining feature selection with common sense(meaningfor instance, trying not to put a striker to leftback)'

# %%
import pandas as pd
import requests
import datetime
from lxml import etree
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from scipy.io import arff
import numpy as np
import random
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from array import array

# %%
dbase=pd.read_csv("Fifa 23 Players Data.csv")

# %%
best_team=[]
tempp=0
tempp2=[]
for i,p in dbase.iterrows():
    if p["Best Position"]!="GK":
        pass
    elif int(p[69])> tempp:
        tempp=int(p[69])
        tempp2=[]
        tempp2.append(i)
    elif int(p[69])== tempp:
        tempp2.append(i)
best_team.append(tempp2)
tempp=0
tempp2=[]

for i,p in dbase.iterrows():
    if p["Best Position"]!="LB" and p["Best Position"]!="LWB" and p["Best Position"]!="LM":
        pass
    elif int(p["Reactions"])+int(p["Vision"])> tempp:
        tempp=int(p["Reactions"])+int(p["Vision"])
        tempp2=[]
        tempp2.append(i)
    elif int(p["Reactions"])+int(p["Vision"])== tempp:
        tempp2.append(i)
best_team.append(tempp2)
tempp=0
tempp2=[]
for i,p in dbase.iterrows():
    if p["Best Position"]!="LB" and p["Best Position"]!="LWB" and p["Best Position"]!="CB" and p["Best Position"]!="RB" and p["Best Position"]!="RWB" and p["Best Position"]!="CDM":
        pass
    elif int(p["Finishing"])+int(p["LongPassing"])+int(p["BallControl"])+int(p["Shot Power"])> tempp:
        tempp=int(p["Finishing"])+int(p["LongPassing"])+int(p["BallControl"])+int(p["Shot Power"])
        tempp2=[]
        tempp2.append(i)
    elif int(p["Finishing"])+int(p["LongPassing"])+int(p["BallControl"])+int(p["Shot Power"])== tempp:
        tempp2.append(i)
best_team.append(tempp2)
tempp=0
tempp2=[]
for i,p in dbase.iterrows():
    if p["Best Position"]!="LB" and p["Best Position"]!="LWB" and p["Best Position"]!="CB" and p["Best Position"]!="RB" and p["Best Position"]!="RWB" and p["Best Position"]!="CDM":
        pass
    elif int(p["Short Passing"])+int(p["LongPassing"])+int(p["BallControl"])+int(p["Reactions"])+int(p["Shot Power"])> tempp:
        tempp=int(p["Short Passing"])+int(p["LongPassing"])+int(p["BallControl"])+int(p["Reactions"])+int(p["Shot Power"])
        tempp2=[]
        tempp2.append(i)
    elif int(p["Short Passing"])+int(p["LongPassing"])+int(p["BallControl"])+int(p["Reactions"])+int(p["Shot Power"])== tempp:
        tempp2.append(i)
best_team.append(tempp2)
tempp=0
tempp2=[]
for i,p in dbase.iterrows():
    if p["Best Position"]!="RB" and p["Best Position"]!="RWB" and p["Best Position"]!="RM":
        pass
    elif int(p["BallControl"])+int(p["Sprint Speed"])+int(p["Agility"])> tempp:
        tempp=int(p["BallControl"])+int(p["Sprint Speed"])+int(p["Agility"])
        tempp2=[]
        tempp2.append(i)
    elif int(p["BallControl"])+int(p["Sprint Speed"])+int(p["Agility"])== tempp:
        tempp2.append(i)
best_team.append(tempp2)
tempp=0
tempp2=[]
for i,p in dbase.iterrows():
    if p["Best Position"]!="CDM" and p["Best Position"]!="CM" and p["Best Position"]!="LM" and p["Best Position"]!="CAM":
        pass
    elif int(p["LongPassing"])+int(p["Interceptions"])+int(p["Positioning"])> tempp:
        tempp=int(p["LongPassing"])+int(p["Interceptions"])+int(p["Positioning"])
        tempp2=[]
        tempp2.append(i)
    elif int(p["LongPassing"])+int(p["Interceptions"])+int(p["Positioning"])== tempp:
        tempp2.append(i)
best_team.append(tempp2)
tempp=0
tempp2=[]
for i,p in dbase.iterrows():
    if p["Best Position"]!="CDM" and p["Best Position"]!="CM" and p["Best Position"]!="CF" and p["Best Position"]!="CAM":
        pass
    elif int(p["Overall"])+int(p["Short Passing"])+int(p["Volleys"])+int(p["Dribbling"])+int(p["BallControl"])+int(p["Interceptions"])> tempp:
        tempp=int(p["Overall"])+int(p["Short Passing"])+int(p["Volleys"])+int(p["Dribbling"])+int(p["BallControl"])+int(p["Interceptions"])
        tempp2=[]
        tempp2.append(i)
    elif int(p["Overall"])+int(p["Short Passing"])+int(p["Volleys"])+int(p["Dribbling"])+int(p["BallControl"])+int(p["Interceptions"])== tempp:
        tempp2.append(i)
best_team.append(tempp2)
tempp=0
tempp2=[]
for i,p in dbase.iterrows():
    if p["Best Position"]!="CDM" and p["Best Position"]!="CM" and p["Best Position"]!="RM" and p["Best Position"]!="CAM":
        pass
    elif int(p["Finishing"])+int(p["Overall"])+int(p["LongPassing"])+int(p["BallControl"])> tempp:
        tempp=int(p["Finishing"])+int(p["Overall"])+int(p["LongPassing"])+int(p["BallControl"])
        tempp2=[]
        tempp2.append(i)
    elif int(p["Finishing"])+int(p["Overall"])+int(p["LongPassing"])+int(p["BallControl"])== tempp:
        tempp2.append(i)
best_team.append(tempp2)
tempp=0
tempp2=[]
for i,p in dbase.iterrows():
    if p["Best Position"]!="LM" and p["Best Position"]!="LW" and p["Best Position"]!="LF" and p["Best Position"]!="CF" and p["Best Position"]!="ST":
        pass
    elif int(p["Dribbling"])> tempp:
        tempp=int(p["Dribbling"])
        tempp2=[]
        tempp2.append(i)
    elif int(p["Dribbling"])== tempp:
        tempp2.append(i)
best_team.append(tempp2)
tempp=0
tempp2=[]
for i,p in dbase.iterrows():
    if p["Best Position"]!="CAM" and p["Best Position"]!="LW" and p["Best Position"]!="LF" and p["Best Position"]!="CF" and p["Best Position"]!="ST" and p["Best Position"]!="RW" and p["Best Position"]!="RF":
        pass
    elif int(p["Overall"])+int(p["Dribbling"])+int(p["Agility"])> tempp:
        tempp=int(p["Overall"])+int(p["Dribbling"])+int(p["Agility"])
        tempp2=[]
        tempp2.append(i)
    elif int(p["Overall"])+int(p["Dribbling"])+int(p["Agility"])== tempp:
        tempp2.append(i)
best_team.append(tempp2)
tempp=0
tempp2=[]
for i,p in dbase.iterrows():
    if p["Best Position"]!="RM" and p["Best Position"]!="RW" and p["Best Position"]!="RF" and p["Best Position"]!="CF" and p["Best Position"]!="ST":
        pass
    elif int(p["Crossing"])+int(p["Stamina"])+int(p["Positioning"])> tempp:
        tempp=int(p["Crossing"])+int(p["Stamina"])+int(p["Positioning"])
        tempp2=[]
        tempp2.append(i)
    elif int(p["Crossing"])+int(p["Stamina"])+int(p["Positioning"]) == tempp:
        tempp2.append(i)
best_team.append(tempp2)

# %%
for c in range(len(best_team)):
    for u in range(len(best_team[c])):
        print(c)
        print(dbase.iloc[best_team[c][u]]["Full Name"])
# Out:
# 0
# Ederson Santana de Moraes
# 1
# Sadio Mané
# 2
# Emre Can
# 3
# Joshua Kimmich
# 4
# Moussa Diaby
# 5
# Leon Goretzka
# 6
# Thiago Alcântara
# 7
# Lionel Messi
# 8
# Neymar da Silva Santos Jr.
# 9
# Lionel Messi
# 9
# Kylian Mbappé
# 9
# Neymar da Silva Santos Jr.
# 10
# Mohamed Salah
